# %% [markdown]
# # Este é um exemplo de Notebook
#
# <p>Você pode criar parágrafos simplesmente escrevendo o texto como preferir.</p>
#
# Para códigos, adicione <code>&#96;</code> antes e <code>&#96;</code> depois para códigos de uma linha, e <code>&#96;&#96;&#96;</code> antes e <code>&#96;&#96;&#96;</code> depois para códigos de várias linhas. **Exemplo de uma linha:** `print(123)`.
#
# **Exemplo de várias linhas:**
#
# ```python
# lista = [
#     {'nome': 'Luiz', 'sobrenome': 'miranda'},
#     {'nome': 'Maria', 'sobrenome': 'Oliveira'},
#     {'nome': 'Daniel', 'sobrenome': 'Silva'},
#     {'nome': 'Eduardo', 'sobrenome': 'Moreira'},
#     {'nome': 'Aline', 'sobrenome': 'Souza'},
# ]
# ```
#
# ## Negrito e itálico
#
# * \** e \** - **Negrito**
# * \* e \* - *Itálico*
#
# ## Blockquote
#
# Responder as perguntas dos coleguinhas, pode te ajudar a aprender muito mais.
#
# > If you can't explain it simply, you don't understand it well enough.
# > Albert Einstein
#
# ## Listas
#
# Aqui uma lista ordenada:
#
# 1. Albert Einstein
# 2. Carl Sagan
# 3. Guido van Rossum
#
# Aqui está uma lista não ordenada:
#
# - Albert Einstein
# - Carl Sagan
# - Guido van Rossum
#
# ## Imagem e links
#
# Olha só:
#
# ![A logo do Python](https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg)
#
# A imagem acima está [neste link](https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg).
#
# ## Tabela
#
# Abaixo uma tabela HTML:
#
# | Aqui temos uma tabela | Com mais uma coluna |
# |-----------------------|---------------------|
# | Aqui temos uma linha  | Outra coluna        |
# | Aqui temos uma linha  | Outra coluna        |
# | Aqui temos uma linha  | Outra coluna        |
# | Coluna                | Outra               |
#
# ## Abaixo uma linha horizontal
#
# a
#
# ---
#
# b
#
# ## HTML puro
#
# <div style="padding: 30px; margin: 10px; background: #ccc;">
# <p>Aqui vemos um &lt;p&gt;. Você pode usar qualquer tag HTML normal.</p>
# </div>

# %% [markdown]
# # Renderizando HTML

# %%
# %%HTML
# <span style="color: red;">
# <b>ISSO É HTML</b><br />
# Este texto deve estar vermelho.
# </span>
# Out:
# <span style="color: red;">
# <b>ISSO É HTML</b><br />
# Este texto deve estar vermelho.
# </span>

# %%
# %%HTML
# <h1>Vídeo do youtube</h1>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/T17BTNKBeJY" frameborder="0"></iframe>
# Out:
# <h1>Vídeo do youtube</h1>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/T17BTNKBeJY" frameborder="0"></iframe>

# %% [markdown]
# # Gráficos com matplotlib

# %% [markdown]
# Um exemplo de USO do módulo `matplotlib`.
#
# Primeiro vamos instalar o módulo usando `!` antes do comando.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in .\venv\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in .\venv\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in .\venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in .\venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %% [markdown]
# # Comandos no seu computador

# %% [markdown]
# Use o `!` para comandos do seu computador.

# %%
# !ping 127.0.0.1
# Out:
# Pinging 127.0.0.1 with 32 bytes of data:
# Reply from 127.0.0.1: bytes=32 time<1ms TTL=128
# Reply from 127.0.0.1: bytes=32 time<1ms TTL=128
# Reply from 127.0.0.1: bytes=32 time<1ms TTL=128
# Reply from 127.0.0.1: bytes=32 time<1ms TTL=128
#
# Ping statistics for 127.0.0.1:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 0ms, Maximum = 0ms, Average = 0ms

# %% [markdown]
# # timeit
#
# Você pode ver quanto tempo levou para realizar alguma operação com `%%timeit`.

# %%
# %%timeit
lista = [x * 2 for x in range(100000)]
# Out:
# 4.36 ms ± 17.6 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Exibindo Pandas Dataframe

# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in .\venv\Lib\site-packages (2.5.1)
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2.3.3 in .\venv\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 9.9/9.9 MB 79.9 MB/s  0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(18,5))
df
# Out:
#            0         1         2         3         4
# 0   0.483687  0.929835  1.512350  0.604956 -0.265302
# 1   1.923336  1.004098 -0.253841 -0.375284 -1.177674
# 2  -0.683279  2.084590 -0.357805 -1.386209  0.351826
# 3  -0.090446  1.891218 -0.751521 -0.747424 -0.441199
# 4  -0.487150  1.226920 -0.481443 -0.462561  0.870370
# 5   0.117049  0.526263 -0.227188 -0.558571  0.261546
# 6   1.108883  0.849442  1.259146 -1.204067  0.842330
# 7   0.109655 -0.387896 -1.906277  1.941439  0.180825
# 8   1.115196  0.464907 -0.895837  0.577624  1.257874
# 9  -0.325948 -0.437638 -1.119877  1.528973  0.308189
# 10  0.593023 -0.573919 -0.289310  1.157366 -1.803327
# 11 -0.440077 -0.704190  0.422053 -1.433103  0.253100
# 12  1.320237  0.893970  1.051522  0.414835 -0.704725
# 13 -1.307285 -0.744984 -0.341848 -0.995420 -1.905374
# 14 -1.700404 -0.617902 -1.606366 -0.118234 -0.288358
# 15  0.122534 -0.727757  1.287982  2.146802 -0.834571
# 16  1.161000 -0.588339 -0.720332 -0.484218 -0.324130
# 17  0.804771 -1.307417  0.170626 -0.227261 -1.545518
